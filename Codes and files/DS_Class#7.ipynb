# %% [markdown]
# ### LOC, ILOC | GROUPBY

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("netflix_titles.csv")
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ### LOC

# %%
# Label based selection
# data.loc[<row lebels>,<column labels>]
data.loc[:,"type"]
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8802      Movie
# 8803    TV Show
# 8804      Movie
# 8805      Movie
# 8806      Movie
# Name: type, Length: 8807, dtype: object

# %%
data.loc[:,["country", "type"]]
# Out:
#             country     type
# 0     United States    Movie
# 1      South Africa  TV Show
# 2               NaN  TV Show
# 3               NaN  TV Show
# 4             India  TV Show
# ...             ...      ...
# 8802  United States    Movie
# 8803            NaN  TV Show
# 8804  United States    Movie
# 8805  United States    Movie
# 8806          India    Movie
#
# [8807 rows x 2 columns]

# %%
data.loc[:,["type"]].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# dtype: int64

# %% [markdown]
# ##### data[column]
# ##### data.loc[:[column]]
# ##### both are same if we are not working with limited rows

# %%
data.loc[1:"cast"].value_counts()
# Out:
# show_id  type   title                director             cast                                                                                                                                                                           country                                                 date_added          release_year  rating  duration  listed_in                                         description
# s10      Movie  The Starling         Theodore Melfi       Melissa McCarthy, Chris O'Dowd, Kevin Kline, Timothy Olyphant, Daveed Diggs, Skyler Gisondo, Laura Harrier, Rosalind Chao, Kimberly Quinn, Loretta Devine, Ravi Kapoor         United States                                           September 24, 2021  2021          PG-13   104 min   Comedies, Dramas                                  A woman adjusting to life after a loss contends with a feisty bird that's taken over her garden — and a husband who's struggling to find a way forward.     1
# ...

# %%
data.loc[1,"cast"]
# Out:
# 'Ama Qamata, Khosi Ngema, Gail Mabalane, Thabang Molaba, Dillon Windvogel, Natasha Thahane, Arno Greeff, Xolile Tshabalala, Getmore Sithole, Cindy Mahlangu, Ryle De Morny, Greteli Fincham, Sello Maake Ka-Ncube, Odwa Gwanya, Mekaila Mathys, Sandi Schultz, Duane Williams, Shamilla Miller, Patrick Mofokeng'

# %%
arr = data.loc[1,"cast"].split(", ")
len(arr)
# Out:
# 19

# %% [markdown]
# # Home Task 1
# ### Question 1:
# #### Create a new column in the provided dataset. Column name should be num_of_cast. The assignment was already explained in class. You have to append or add a column in the dataset which contains the total number of cast in that particular movie or Tv-Show.

# %%
data['cast'] = data['cast'].fillna(0)
data
Value = data.loc[:, ["cast"]].value_counts()
data['num_of_cast'] = data.loc[:, ["cast"]].value_counts().values.repeat(Value)
#data
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                     0  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # ILOC

# %%
# index label based selection iloc
data.iloc[3:8,]
# Out:
#   show_id     type                             title  \
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
#
#                         director  \
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
#
#                                                 cast  \
# 3                                                  0
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
#
#                                              country          date_added  \
# ...

# %%
data.iloc[[4]]
# Out:
#   show_id     type         title director  \
# 4      s5  TV Show  Kota Factory      NaN
#
#                                                 cast country  \
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
#
#            date_added  release_year rating   duration  \
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  num_of_cast
# 4  In a city of coaching centers known to train I...          825

# %%
data.iloc[4]
# Out:
# show_id                                                        s5
# type                                                      TV Show
# title                                                Kota Factory
# director                                                      NaN
# cast            Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# country                                                     India
# date_added                                     September 24, 2021
# release_year                                                 2021
# rating                                                      TV-MA
# duration                                                2 Seasons
# listed_in       International TV Shows, Romantic TV Shows, TV ...
# description     In a city of coaching centers known to train I...
# num_of_cast                                                   825
# Name: 4, dtype: object

# %%
data.loc[:,"title"]
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
data.loc[data["title"] == "Kota Factory"]
# Out:
#   show_id     type         title director  \
# 4      s5  TV Show  Kota Factory      NaN
#
#                                                 cast country  \
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
#
#            date_added  release_year rating   duration  \
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  num_of_cast
# 4  In a city of coaching centers known to train I...          825

# %%
data.loc[data["title"] != "Kota Factory"]
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                     0  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# One Hot Encoding
data["cast"] = data['cast'].replace(np.nan,"None")
data["director"] = data['director'].replace(np.nan, "None")

data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water             None
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans             None
# 4         s5  TV Show           Kota Factory             None
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb             None
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                     0  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.loc[data["release_year"]>2020]
# Out:
#      show_id     type                      title         director  \
# 1         s2  TV Show              Blood & Water             None
# 2         s3  TV Show                  Ganglands  Julien Leclercq
# 3         s4  TV Show      Jailbirds New Orleans             None
# 4         s5  TV Show               Kota Factory             None
# 5         s6  TV Show              Midnight Mass    Mike Flanagan
# ...      ...      ...                        ...              ...
# 1468   s1469    Movie  What Happened to Mr. Cha?     Kim Dong-kyu
# 1551   s1552  TV Show                      Hilda             None
# 1696   s1697  TV Show               Polly Pocket             None
# 2920   s2921  TV Show              Love Is Blind             None
# 8437   s8438  TV Show     The Netflix Afterparty             None
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
#  12  num_of_cast   8807 non-null   int64
# dtypes: int64(2), object(11)
# memory usage: 894.6+ KB

# %%
data.loc[data.release_year>=2020].sum()
# Out:
# C:\Users\ANONYM~1\AppData\Local\Temp/ipykernel_6044/1543780818.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.loc[data.release_year>=2020].sum()
# show_id         s1s2s3s4s5s6s7s9s10s11s12s13s14s15s16s17s18s19...
# type            MovieTV ShowTV ShowTV ShowTV ShowTV ShowMovieT...
# title           Dick Johnson Is DeadBlood & WaterGanglandsJail...
# director        Kirsten JohnsonNoneJulien LeclercqNoneNoneMike...
# date_added      September 25, 2021September 24, 2021September ...
# release_year                                              3121492
# rating          PG-13TV-MATV-MATV-MATV-MATV-MAPGTV-14PG-13TV-M...
# duration        90 min2 Seasons1 Season1 Season2 Seasons1 Seas...
# listed_in       DocumentariesInternational TV Shows, TV Dramas...
# ...

# %%
data.loc[data.release_year>=2020].count()
# Out:
# show_id         1545
# type            1545
# title           1545
# director        1545
# cast            1545
# country         1235
# date_added      1545
# release_year    1545
# rating          1545
# duration        1545
# listed_in       1545
# description     1545
# num_of_cast     1545
# dtype: int64

# %% [markdown]
# # Groupby

# %%
# similar elements get into groups

data.groupby("type")["rating"].sum()
# Out:
# type
# Movie      PG-13PGTV-MAPG-13TV-MATV-PGTV-MATV-14TV-PGTV-Y...
# TV Show    TV-MATV-MATV-MATV-MATV-MATV-14TV-MATV-MATV-MAT...
# Name: rating, dtype: object

# %% [markdown]
# # Home task 2
# ### Question 2:
# #### In the provided dataset count how many number of tv-shows and movies of each genre are there using group by or whichever other method you see fit.

# %%
t2 = data.groupby(['type']).count()
print(t2)
# Out:
#          show_id  title  director  cast  country  date_added  release_year  \
# type
# Movie       6131   6131      6131  6131     5691        6131          6131
# TV Show     2676   2676      2676  2676     2285        2666          2676
#
#          rating  duration  listed_in  description  num_of_cast
# type
# Movie      6129      6128       6131         6131         6131
# TV Show    2674      2676       2676         2676         2676
